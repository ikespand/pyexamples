# %% [markdown]
# # Experiments with backtesting.py
# This notebook is to explore the `backtesting.py` to evaluate strategy:
# 1. Based on conventional TA (talib etc.)
# 2. See how can we introduce ML model as TA

# %% [markdown]
# Install ta-lib on Mac with brew first `brew install ta-lib` and then `pip install TA-Lib`

# %%
import pandas as pd
import numpy as np
from backtesting import Backtest, Strategy
from backtesting.lib import crossover
from backtesting.test import SMA, GOOG
import yfinance as yf
import talib 
from bt_utils import get_stock_data

# %% [markdown]
# ### 1. Standard Examples
# First, use standard example; where goal is just to see how we can use the library. In the following, we will use SMA as an indicator which is already available in `backtesting.py`. We will also use stop loss and take profit to limit the exposure and to ensure risk-reward ratio.

# %%
class SmaCrossWithSLTP(Strategy):
    short_window = 10  # Fast SMA
    long_window = 20   # Slow SMA
    stop_loss_pct = 0.02   # 2% Stop Loss
    take_profit_pct = 0.04  # 4% Take Profit
    
    # All the necessary indicator needs to define in the init method
    def init(self):
        self.sma_short = self.I(SMA, self.data.Close, self.short_window)
        self.sma_long = self.I(SMA, self.data.Close, self.long_window)
    
    # It defines the logic of the strategy
    def next(self):
        price = self.data.Close[-1]  # Current price
        if crossover(self.sma_short, self.sma_long):  # Buy condition
            stop_loss = price * (1 - self.stop_loss_pct)
            take_profit = price * (1 + self.take_profit_pct)
            self.buy(sl=stop_loss, tp=take_profit)  # Order with SL and TP
        
        elif crossover(self.sma_long, self.sma_short):  # Sell condition
            self.position.close()  # Close existing position

# Load sample data which comes with the library to test
df = GOOG

# Run Backtest
bt = Backtest(df, SmaCrossWithSLTP, cash=10000, commission=0.002)
stats = bt.run()
print(stats)
# bt.plot()
# Out:
# Start                     2004-08-19 00:00:00
# End                       2013-03-01 00:00:00
# Duration                   3116 days 00:00:00
# Exposure Time [%]                     9.82309
# Equity Final [$]                  11532.01791
# Equity Peak [$]                   12667.87271
# Commissions [$]                    2041.36509
# Return [%]                           15.32018
# Buy & Hold Return [%]               607.37036
# Return (Ann.) [%]                     1.68634
# Volatility (Ann.) [%]                 6.32304
# CAGR [%]                              1.15945
# Sharpe Ratio                           0.2667
# Sortino Ratio                         0.40031
# Calmar Ratio                          0.14875
# Alpha [%]                            -4.51391
# Beta                                  0.03266
# Max. Drawdown [%]                   -11.33648
# Avg. Drawdown [%]                    -3.53535
# Max. Drawdown Duration      742 days 00:00:00
# Avg. Drawdown Duration      172 days 00:00:00
# # Trades                                   47
# Win Rate [%]                         46.80851
# Best Trade [%]                        5.31909
# Worst Trade [%]                      -4.00182
# Avg. Trade [%]                        0.71138
# Max. Trade Duration          26 days 00:00:00
# Avg. Trade Duration           6 days 00:00:00
# Profit Factor                         1.81242
# Expectancy [%]                        0.75151
# SQN                                   1.67091
# Kelly Criterion                        0.1761
# _strategy                    SmaCrossWithSLTP
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ## 2. Integrating other indicators from TA-LIB
# Now, moving to `ta-lib` for more indicators. In the following, we will use RSI along with SL and TP.

# %%
class RsiSmaStrategy(Strategy):
    rsi_period = 14    # RSI period
    rsi_buy = 30       # RSI oversold threshold
    rsi_sell = 70      # RSI overbought threshold
    stop_loss_pct = 0.02  # 2% stop-loss
    take_profit_pct = 0.05  # 5% take-profit

    def init(self):    
        self.rsi = self.I(talib.RSI, self.data.Close, self.rsi_period)

    def next(self):
        # Entry Condition: RSI below 30 & SMA crossover
        if self.rsi[-1] < self.rsi_buy :
            price = self.data.Close[-1]
            sl = price * (1 - self.stop_loss_pct)  # Stop-Loss 2% below entry
            tp = price * (1 + self.take_profit_pct)  # Take-Profit 5% above entry
            self.buy(sl=sl, tp=tp)  # Place order with SL & TP

        # Exit Condition: RSI above 70 OR SMA crossover in opposite direction
        elif self.rsi[-1] > self.rsi_sell:
            self.position.close()

df = get_stock_data("AAPL")

# Run Backtest
bt = Backtest(df, RsiSmaStrategy, cash=10000, commission=0.002)
stats = bt.run()

# Print Results
print(stats)
# Save HTML file for plots for in-browser visualization
bt.plot(filename="rsi_strategy.html")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Backtest.run:   0%|          | 0/527 [00:00<?, ?it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=17: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=403: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=409: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=505: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Start                     2022-01-03 00:00:00
# End                       2024-02-29 00:00:00
# Duration                    787 days 00:00:00
# Exposure Time [%]                     7.01107
# Equity Final [$]                  11851.73611
# Equity Peak [$]                   11851.73611
# Commissions [$]                     298.72019
# Return [%]                           18.51736
# Buy & Hold Return [%]                13.25856
# Return (Ann.) [%]                     8.21925
# Volatility (Ann.) [%]                 8.25065
# CAGR [%]                              5.59059
# Sharpe Ratio                           0.9962
# Sortino Ratio                         2.07463
# Calmar Ratio                           2.1929
# Alpha [%]                            17.55187
# Beta                                  0.07282
# Max. Drawdown [%]                    -3.74812
# Avg. Drawdown [%]                    -2.09708
# Max. Drawdown Duration       16 days 00:00:00
# Avg. Drawdown Duration        7 days 00:00:00
# # Trades                                    7
# Win Rate [%]                         85.71429
# Best Trade [%]                        6.03599
# Worst Trade [%]                      -2.45811
# Avg. Trade [%]                        2.88129
# Max. Trade Duration          14 days 00:00:00
# Avg. Trade Duration           7 days 00:00:00
# Profit Factor                         9.30849
# Expectancy [%]                        2.91759
# SQN                                    2.5783
# Kelly Criterion                       0.76244
# _strategy                      RsiSmaStrategy
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object
# GridPlot(id='p3233', ...)

# %% [markdown]
# ## 3. Integrating a black-box indicator (e.g., ML model)
# Now we will add a black-box function which can be an ML model which can provide BUY or SELL signal. We will pass the dataframe containing the features and function can use this to predict the position. This then can be used in `next` function.

# %%
def dummy_ml_model(df):
    """
    Simulated ML model that predicts BUY signals. We don't consider SELL (short positions).
    :param df: DataFrame of last `N` rows (OHLCV features).
    :return: 1 if BUY signal, else 0.
    """
    # Simulated logic: Buy if the last row closes lower than the first row in the window
    if df.iloc[-1]['Close'] < df.iloc[0]['Close']:  
        return 1  # BUY Signal
    return 0  # No action

class MLTradingStrategy(Strategy):
    feature_window = 5 # window size for features 
    stop_loss_pct = 0.02 
    take_profit_pct = 0.05 

    def init(self):
        pass

    def next(self):
        N = self.feature_window  
        # Ensure enough data to generate features
        if len(self.data.Close) < N:
            return 

        # Extract last `N` rows into a DataFrame
        df = pd.DataFrame({
            "Open": self.data.Open[-N:],
            "High": self.data.High[-N:],
            "Low": self.data.Low[-N:],
            "Close": self.data.Close[-N:],
            "Volume": self.data.Volume[-N:],
        })

        # Pass last `N` rows to ML model
        signal = dummy_ml_model(df)  

        # ML suggests BUY signal
        if signal == 1:  
            price = self.data.Close[-1]
            sl = price * (1 - self.stop_loss_pct)  
            tp = price * (1 + self.take_profit_pct) 
            self.buy(sl=sl, tp=tp)  

df = get_stock_data("AAPL") 

# Run Backtest
bt = Backtest(df, MLTradingStrategy, cash=10000, commission=0.002)
stats = bt.run()

# Print Results
print(stats)
bt.plot(filename="ml__strategy.html")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Backtest.run:   0%|          | 0/541 [00:00<?, ?it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=17: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=25: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=26: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=30: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=31: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=38: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=46: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=47: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:   9%|▉         | 50/541 [00:00<00:01, 312.14it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=63: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=64: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=67: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=70: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=71: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=72: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=73: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=74: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=75: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=80: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  16%|█▌        | 87/541 [00:00<00:01, 336.33it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=92: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=98: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=99: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=107: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=109: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=113: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=125: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  23%|██▎       | 127/541 [00:00<00:01, 359.57it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=161: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=162: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=168: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=170: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=184: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=190: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=194: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=195: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=214: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  43%|████▎     | 234/541 [00:00<00:00, 615.61it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=236: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=237: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=244: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=245: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=250: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=251: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=252: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=254: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=279: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=280: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=284: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=286: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=287: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=288: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=289: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=292: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=298: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=299: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=300: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=310: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  58%|█████▊    | 314/541 [00:00<00:00, 678.34it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=319: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=320: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=327: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=328: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=329: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=330: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=336: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=342: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=344: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=345: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=350: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=351: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=360: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=381: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=382: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=383: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=390: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=391: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=397: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=401: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=402: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  74%|███████▍  | 402/541 [00:00<00:00, 744.22it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=403: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=404: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=405: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=406: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=409: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=410: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=423: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=424: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=426: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=427: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=428: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=431: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=432: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=433: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=437: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=438: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=451: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=454: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=455: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=458: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=459: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=460: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Backtest.run:  88%|████████▊ | 478/541 [00:00<00:00, 644.54it/s]/Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=479: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=480: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=481: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=483: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=488: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=495: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=497: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=498: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=499: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=500: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=505: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=506: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=511: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=512: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=525: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=530: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=531: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=533: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=535: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=536: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=539: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# /Users/ikespand/anaconda3/envs/py311/lib/python3.11/site-packages/backtesting/backtesting.py:955: UserWarning: time=541: Broker canceled the relative-sized order due to insufficient margin.
#   warnings.warn(
# Start                     2022-01-03 00:00:00
# End                       2024-02-29 00:00:00
# Duration                    787 days 00:00:00
# Exposure Time [%]                     70.1107
# Equity Final [$]                   4967.12098
# Equity Peak [$]                   10102.65372
# Commissions [$]                    3503.94424
# Return [%]                          -50.32879
# Buy & Hold Return [%]                 0.57056
# Return (Ann.) [%]                   -27.77201
# Volatility (Ann.) [%]                17.77616
# CAGR [%]                            -20.07333
# Sharpe Ratio                         -1.56232
# Sortino Ratio                         -1.4636
# Calmar Ratio                         -0.51764
# Alpha [%]                           -50.67527
# Beta                                  0.60726
# Max. Drawdown [%]                   -53.65079
# Avg. Drawdown [%]                   -27.12878
# Max. Drawdown Duration      778 days 00:00:00
# Avg. Drawdown Duration      391 days 00:00:00
# # Trades                                  140
# Win Rate [%]                         26.42857
# Best Trade [%]                        7.12231
# Worst Trade [%]                      -6.21131
# Avg. Trade [%]                       -0.10062
# Max. Trade Duration          20 days 00:00:00
# Avg. Trade Duration           4 days 00:00:00
# Profit Factor                         0.95705
# Expectancy [%]                       -0.05449
# SQN                                  -0.67628
# Kelly Criterion                       -0.0837
# _strategy                   MLTradingStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# GridPlot(id='p3587', ...)
